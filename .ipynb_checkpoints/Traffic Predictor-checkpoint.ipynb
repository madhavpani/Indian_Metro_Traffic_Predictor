# %% [markdown]
# ## Indian Metro Traffic Prediction

# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Import Dataset

# %%
traffic_df = pd.read_csv('Train.csv')
traffic_df.head(3)
# Out:
#              date_time is_holiday  air_pollution_index  humidity  wind_speed  \
# 0  2012-10-02 09:00:00        NaN                  121        89           2
# 1  2012-10-02 10:00:00        NaN                  178        67           3
# 2  2012-10-02 11:00:00        NaN                  113        66           3
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# 0             329                    1          1       288.28       0.0
# 1             330                    1          1       289.36       0.0
# 2             329                    2          2       289.58       0.0
#
#    snow_p_h  clouds_all weather_type weather_description  traffic_volume
# 0       0.0          40       Clouds    scattered clouds            5545
# 1       0.0          75       Clouds       broken clouds            4516
# 2       0.0          90       Clouds     overcast clouds            4767

# %% [markdown]
# #### Categorical Columns

# %%
cat_cols = traffic_df.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['date_time', 'is_holiday', 'weather_type', 'weather_description'], dtype='object')

# %% [markdown]
# #### Numerical Columns

# %%
num_cols = traffic_df.select_dtypes(include='number').columns
num_cols
# Out:
# Index(['air_pollution_index', 'humidity', 'wind_speed', 'wind_direction',
#        'visibility_in_miles', 'dew_point', 'temperature', 'rain_p_h',
#        'snow_p_h', 'clouds_all', 'traffic_volume'],
#       dtype='object')

# %% [markdown]
# #### Shape

# %%
traffic_df.shape
# Out:
# (33750, 15)

# %% [markdown]
# #### Correlation

# %%
traffic_df[num_cols].corr()
# Out:
#                      air_pollution_index  humidity  wind_speed  \
# air_pollution_index             1.000000 -0.000277   -0.004166
# humidity                       -0.000277  1.000000   -0.147042
# wind_speed                     -0.004166 -0.147042    1.000000
# wind_direction                  0.000749 -0.046268    0.191320
# visibility_in_miles             0.003499  0.005510   -0.005160
# dew_point                       0.003499  0.005510   -0.005160
# temperature                     0.005368  0.033273   -0.052856
# rain_p_h                        0.000443 -0.012161    0.001165
# snow_p_h                        0.007227  0.016625   -0.006534
# clouds_all                     -0.008541  0.014520   -0.004456
# traffic_volume                 -0.003751  0.016455    0.016329
#
#                      wind_direction  visibility_in_miles  dew_point  \
# air_pollution_index        0.000749             0.003499   0.003499
# humidity                  -0.046268             0.005510   0.005510
# ...

# %% [markdown]
# #### Quantiles and Statistics

# %%
traffic_df.describe()
# Out:
#        air_pollution_index      humidity    wind_speed  wind_direction  \
# count         33750.000000  33750.000000  33750.000000    33750.000000
# mean            154.841422     71.209007      3.378193      199.471852
# std              83.735515     16.852248      2.055792       99.841088
# min              10.000000     13.000000      0.000000        0.000000
# 25%              83.000000     60.000000      2.000000      130.000000
# 50%             155.000000     72.000000      3.000000      200.000000
# 75%             228.000000     85.000000      5.000000      290.000000
# max             299.000000    100.000000     16.000000      360.000000
#
#        visibility_in_miles     dew_point   temperature      rain_p_h  \
# count         33750.000000  33750.000000  33750.000000  33750.000000
# mean              4.989748      4.989748    280.069587      0.448739
# std               2.570021      2.570021     13.415256     53.526500
# ...

# %% [markdown]
# #### DataFrame Information

# %%
traffic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33750 entries, 0 to 33749
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date_time            33750 non-null  object
#  1   is_holiday           43 non-null     object
#  2   air_pollution_index  33750 non-null  int64
#  3   humidity             33750 non-null  int64
#  4   wind_speed           33750 non-null  int64
#  5   wind_direction       33750 non-null  int64
#  6   visibility_in_miles  33750 non-null  int64
#  7   dew_point            33750 non-null  int64
#  8   temperature          33750 non-null  float64
#  9   rain_p_h             33750 non-null  float64
#  10  snow_p_h             33750 non-null  float64
#  11  clouds_all           33750 non-null  int64
#  12  weather_type         33750 non-null  object
#  13  weather_description  33750 non-null  object
#  14  traffic_volume       33750 non-null  int64
# ...

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# #### Type Conversion

# %%
traffic_df['date_time'] = pd.to_datetime(traffic_df['date_time'])

# %% [markdown]
# #### Duplicates Removal

# %%
traffic_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Drop Unwanted Columns

# %%
traffic_df.drop(columns=['is_holiday', 'dew_point'], inplace=True)

# %% [markdown]
# #### Rename Columns

# %%
traffic_df.rename(columns={'date_time':'Date', 'air_pollution_index':'Pol_Index', 'humidity':'Humidity', 'wind_speed':'Wind_Speed',
       'wind_direction':'Wind_Dir', 'visibility_in_miles':'Visibility', 'dew_point':'Dew', 'temperature':'Temperature',
       'rain_p_h':'Rain_P_H', 'snow_p_h':'Snow_P_H', 'clouds_all':'Clouds', 'weather_type':'Weather',
       'weather_description':'Weather_Des', 'traffic_volume':'Traffic_Vol'}, inplace=True)

# %%
traffic_df.head(3)
# Out:
#                  Date  Pol_Index  Humidity  Wind_Speed  Wind_Dir  Visibility  \
# 0 2012-10-02 09:00:00        121        89           2       329           1
# 1 2012-10-02 10:00:00        178        67           3       330           1
# 2 2012-10-02 11:00:00        113        66           3       329           2
#
#    Temperature  Rain_P_H  Snow_P_H  Clouds Weather       Weather_Des  \
# 0       288.28       0.0       0.0      40  Clouds  scattered clouds
# 1       289.36       0.0       0.0      75  Clouds     broken clouds
# 2       289.58       0.0       0.0      90  Clouds   overcast clouds
#
#    Traffic_Vol
# 0         5545
# 1         4516
# 2         4767

# %% [markdown]
# #### Missing Values

# %%
traffic_df.isnull().sum()
# Out:
# Date           0
# Pol_Index      0
# Humidity       0
# Wind_Speed     0
# Wind_Dir       0
# Visibility     0
# Temperature    0
# Rain_P_H       0
# Snow_P_H       0
# Clouds         0
# Weather        0
# Weather_Des    0
# Traffic_Vol    0
# dtype: int64

# %% [markdown]
# #### Feature Engineering

# %%
traffic_df['Month'] = traffic_df['Date'].dt.month
traffic_df['Time'] = traffic_df['Date'].dt.hour
traffic_df.drop(columns='Date', inplace=True)

# %%
traffic_df.head(3)
# Out:
#    Pol_Index  Humidity  Wind_Speed  Wind_Dir  Visibility  Temperature  \
# 0        121        89           2       329           1       288.28
# 1        178        67           3       330           1       289.36
# 2        113        66           3       329           2       289.58
#
#    Rain_P_H  Snow_P_H  Clouds Weather       Weather_Des  Traffic_Vol  Month  \
# 0       0.0       0.0      40  Clouds  scattered clouds         5545     10
# 1       0.0       0.0      75  Clouds     broken clouds         4516     10
# 2       0.0       0.0      90  Clouds   overcast clouds         4767     10
#
#    Time
# 0     9
# 1    10
# 2    11

# %% [markdown]
# #### Categorical Columns Standardization

# %%
traffic_df['Weather'].unique()
# Out:
# array(['Clouds', 'Clear', 'Rain', 'Drizzle', 'Mist', 'Haze', 'Fog',
#        'Thunderstorm', 'Snow', 'Squall', 'Smoke'], dtype=object)

# %%
traffic_df['Weather_Des'].unique()
# Out:
# array(['scattered clouds', 'broken clouds', 'overcast clouds',
#        'sky is clear', 'few clouds', 'light rain',
#        'light intensity drizzle', 'mist', 'haze', 'fog',
#        'proximity shower rain', 'drizzle', 'moderate rain',
#        'heavy intensity rain', 'proximity thunderstorm',
#        'thunderstorm with light rain', 'proximity thunderstorm with rain',
#        'heavy snow', 'heavy intensity drizzle', 'snow',
#        'thunderstorm with heavy rain', 'freezing rain', 'shower snow',
#        'light rain and snow', 'light intensity shower rain', 'SQUALLS',
#        'thunderstorm with rain', 'proximity thunderstorm with drizzle',
#        'thunderstorm', 'Sky is Clear', 'very heavy rain',
#        'thunderstorm with light drizzle', 'light snow',
#        'thunderstorm with drizzle', 'smoke', 'shower drizzle',
#        'light shower snow', 'sleet'], dtype=object)

# %%
traffic_df['Weather'] = traffic_df['Weather'] + ' ' + traffic_df['Weather_Des']
traffic_df.drop(columns='Weather_Des', inplace=True)

# %%
traffic_df.head(3)
# Out:
#    Pol_Index  Humidity  Wind_Speed  Wind_Dir  Visibility  Temperature  \
# 0        121        89           2       329           1       288.28
# 1        178        67           3       330           1       289.36
# 2        113        66           3       329           2       289.58
#
#    Rain_P_H  Snow_P_H  Clouds                  Weather  Traffic_Vol  Month  \
# 0       0.0       0.0      40  Clouds scattered clouds         5545     10
# 1       0.0       0.0      75     Clouds broken clouds         4516     10
# 2       0.0       0.0      90   Clouds overcast clouds         4767     10
#
#    Time
# 0     9
# 1    10
# 2    11

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import string

ps = PorterStemmer()

def transformer(text):
    text = ''.join([i for i in text if i not in string.punctuation])
    tokens = sorted(set(word_tokenize(text.lower())))
    text = [ps.stem(token) for token in tokens if token not in set(stopwords.words('english'))]
    return ' '.join(text)

# %%
traffic_df['Weather'] = traffic_df['Weather'].apply(transformer)
traffic_df.head(3)
# Out:
#    Pol_Index  Humidity  Wind_Speed  Wind_Dir  Visibility  Temperature  \
# 0        121        89           2       329           1       288.28
# 1        178        67           3       330           1       289.36
# 2        113        66           3       329           2       289.58
#
#    Rain_P_H  Snow_P_H  Clouds         Weather  Traffic_Vol  Month  Time
# 0       0.0       0.0      40   cloud scatter         5545     10     9
# 1       0.0       0.0      75    broken cloud         4516     10    10
# 2       0.0       0.0      90  cloud overcast         4767     10    11

# %% [markdown]
# ## EDA

# %% [markdown]
# #### Columns : Pol_Index, Humidity, Wind_Dir, Temperature, Rain_P_H, Snow_P_H, Clouds, Traffic_Vol

# %%
plt.subplots(2, 4, figsize = (17, 10))
plt.subplots_adjust(wspace=0.3, hspace=0.3)

k = 1
for i in ['Pol_Index', 'Humidity', 'Wind_Dir', 'Temperature', 'Rain_P_H', 'Snow_P_H', 'Clouds', 'Traffic_Vol']:
    plt.subplot(2,4,k)
    sns.histplot(x = i, data = traffic_df, kde = True)
    plt.title(f'Distribution of {i}')
    k += 1

plt.show()

# %%
plt.subplots(2, 4, figsize = (17, 10))
plt.subplots_adjust(wspace=0.3, hspace=0.3)

k = 1
for i in ['Pol_Index', 'Humidity', 'Wind_Dir', 'Temperature', 'Rain_P_H', 'Snow_P_H', 'Clouds', 'Traffic_Vol']:
    plt.subplot(2,4,k)
    sns.boxplot(x = i, data = traffic_df)
    plt.title(f'Distribution of {i}')
    k += 1

plt.show()

# %% [markdown]
# #### Columns : Wind_Speed, Visibility, Weather, Month, Time

# %%
traffic_df[['Wind_Speed', 'Visibility', 'Weather', 'Month', 'Time']]=traffic_df[['Wind_Speed', 'Visibility', 'Weather', 'Month', 'Time']].astype(str)

# %%
plt.subplots(2, 3, figsize = (14, 10))
plt.subplots_adjust(wspace=0.3, hspace=0.3)

def percentage(x):
    if x >= 5:
        return f'{x: .1f}%'
        
k = 1
for i in ['Wind_Speed', 'Visibility', 'Weather', 'Month', 'Time']:
    plt.subplot(2,3,k)
    data = dict(traffic_df[i].value_counts())
    plt.pie(x = data.values(), labels = data.keys(), autopct = percentage)
    plt.title(f'{i} vs Traffic Volume')
    k += 1

plt.show()

# %% [markdown]
# ## Data Splitting

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(traffic_df.drop(columns='Traffic_Vol'), traffic_df['Traffic_Vol'], test_size=0.2, random_state=42)
X_train.shape, y_train.shape
# Out:
# ((27000, 12), (27000,))

# %% [markdown]
# ## Data Preprocessing

# %%
wind_speeds = list(dict(traffic_df['Wind_Speed'].value_counts()).keys())[::-1]
visibilities = list(dict(traffic_df['Visibility'].value_counts()).keys())[::-1]

# %% [markdown]
# #### Column Transformer

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.preprocessing import PowerTransformer

ct = ColumnTransformer(transformers=[('scaler', StandardScaler(), ['Pol_Index', 'Wind_Dir', 'Clouds']), 
                                     ('pow_transformer', PowerTransformer(), ['Humidity', 'Temperature', 'Rain_P_H', 'Snow_P_H']), 
                                     ('encoder', OrdinalEncoder(categories=[wind_speeds, visibilities]), 
                                      ['Wind_Speed', 'Visibility']), 
                                     ('onehot', OneHotEncoder(drop='first', sparse_output=False), ['Weather', 'Month', 'Time'])], 
                       remainder='passthrough', sparse_threshold=0)
ct
# Out:
# ColumnTransformer(remainder='passthrough', sparse_threshold=0,
#                   transformers=[('scaler', StandardScaler(),
#                                  ['Pol_Index', 'Wind_Dir', 'Clouds']),
#                                 ('pow_transformer', PowerTransformer(),
#                                  ['Humidity', 'Temperature', 'Rain_P_H',
#                                   'Snow_P_H']),
#                                 ('encoder',
#                                  OrdinalEncoder(categories=[['16', '14', '15',
#                                                              '13', '12', '11',
#                                                              '10', '9', '8',
#                                                              '0', '7', '6', '5',
#                                                              '1', '4', '3',
#                                                              '2'],
#                                                             ['9', '8', '2', '7',
# ...

# %% [markdown]
# ## Model Selection

# %%
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, HistGradientBoostingRegressor, ExtraTreesRegressor

models = {
    'lin_reg': LinearRegression(),
    'dt': DecisionTreeRegressor(),
    'svm': SVR(),
    'knn': KNeighborsRegressor(),
    'random': RandomForestRegressor(),
    'gbt': GradientBoostingRegressor(),
    'hgbt': HistGradientBoostingRegressor(),
    'extra': ExtraTreesRegressor()
}

# %%
for model in models:
    pipe = Pipeline([('ct', ct), (f'{model}', models[model])])
    scores = cross_val_score(pipe, traffic_df.drop(columns='Traffic_Vol'), traffic_df['Traffic_Vol'], cv = 5)
    print(f'{model}: ')
    print(f'{scores}, {scores.mean()}')
    print('---------------------------------')
# Out:
# lin_reg:
# [       nan 0.77107876 0.77181765 0.76947583        nan], nan
# ---------------------------------
# dt:
# [       nan 0.53451546 0.540417   0.52856298        nan], nan
# ---------------------------------
# svm:
# [       nan 0.00933772 0.00935118 0.00575953        nan], nan
# ---------------------------------
# knn:
# [       nan 0.15688613 0.14288058 0.15467025        nan], nan
# ---------------------------------
# random:
# [       nan 0.75486413 0.75130389 0.7553737         nan], nan
# ---------------------------------
# gbt:
# [       nan 0.69581486 0.6983115  0.69638861        nan], nan
# ---------------------------------
# hgbt:
# [       nan 0.75915562 0.74982939 0.75824336        nan], nan
# ---------------------------------
# extra:
# [       nan 0.73149588 0.72192624 0.74321881        nan], nan
# ---------------------------------

# %% [markdown]
# ## Model

# %%
pipe = Pipeline([('ct', ct), (f'hgbt', HistGradientBoostingRegressor())])
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('ct',
#                  ColumnTransformer(remainder='passthrough', sparse_threshold=0,
#                                    transformers=[('scaler', StandardScaler(),
#                                                   ['Pol_Index', 'Wind_Dir',
#                                                    'Clouds']),
#                                                  ('pow_transformer',
#                                                   PowerTransformer(),
#                                                   ['Humidity', 'Temperature',
#                                                    'Rain_P_H', 'Snow_P_H']),
#                                                  ('encoder',
#                                                   OrdinalEncoder(categories=[['16',
#                                                                               '14',
#                                                                               '15',
# ...

# %% [markdown]
# ## Model Evaluation

# %%
pipe.score(X_test, y_test)
# Out:
# 0.7888424550971858
